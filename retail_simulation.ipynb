# %%
import random

# Define Personas and their Purchase Habits
personas = {
    "The Morning Commuter": {"percentage": 20, "purchases": {"Spam Musubi": 0.2, "Bubble Tea": 0.5, "Espresso Drinks": 0.5, "Pour Over Coffee": 0.2, "Pastries": 0.5, "Sandwiches": 0.3, "Waffles": 0.2}},
    "The Student": {"percentage": 15, "purchases": {"Spam Musubi": 0.1, "Kimchi Rice": 0.1, "Bubble Tea": 0.5, "Bubble Tea Upgrades": 0.4, "Waffles": 0.2, "Sandwiches": 0.3, "Popcorn Chicken": 0.2}},
    "The Remote Worker": {"percentage": 20, "purchases": {"Spam Musubi": 0.2, "Kimchi Rice": 0.1, "Bubble Tea": 0.5, "Pour Over Coffee": 0.3, "Espresso Drinks": 0.4, "Sparkling Tea Drinks": 0.2, "Pastries": 0.2, "Sandwiches": 0.2}},
    "The Socializer": {"percentage": 10, "purchases": {"Spam Musubi": 0.2, "Bubble Tea Upgrades": 0.3, "Sparkling Tea Drinks": 0.1, "Tea": 0.2, "Garlic Fries": 0.2, "Popcorn Chicken": 0.2}},
    "The Health-Conscious Customer": {"percentage": 5, "purchases": {"Spam Musubi": 0.2, "Kimchi Rice": 0.2, "Tea": 0.2, "Sparkling Tea Drinks": 0.4, "Sandwiches": 0.3, "Waffles": 0.1}},
    "The Family Outing": {"percentage": 15, "purchases": {"Bubble Tea": 1.2, "Bubble Tea Upgrades": .3, "Kids Drinks": 1.2, "Pastries": .4, "Sandwiches": 0.4, "Popcorn Chicken": 0.3, "Garlic Fries": 0.4}},
    "The Connoisseur": {"percentage": 5, "purchases": {"Pour Over Coffee": 0.5, "Espresso Drinks": 0.5 }},
    "The Professional Freelancer": {"percentage": 10, "purchases": {"Kimchi Rice": 0.1, "Espresso Drinks": 1, "Pour Over Coffee": 0.5, "Tea": 0.1, "Sparkling Tea Drinks": 0.2, "Bubble Tea": 0.3, "Pastries": 0.1, "Sandwiches": 0.2}},
}

# New: Define average prices for each menu item
prices = {
    "Espresso Drinks": 6.0,
    "Pour Over Coffee": 5.0,
    "Pastries": 5,
    "Sandwiches": 11.0,
    "Bubble Tea": 6.5,
    "Bubble Tea Upgrades": .75,
    "Tea": 5.0,
    "Sparkling Tea Drinks": 5.0,
    "Kids Drinks": 4.0,
    "Waffles": 5.0,
    "Kimchi Rice": 8.99,
    "Popcorn Chicken": 7.50,
    "Garlic Fries": 6.50,
    "Spam Musubi": 4.50,
}

costs = {
    "Espresso Drinks": 2.0,
    "Pour Over Coffee": 1.5,
    "Pastries": 2.0,
    "Sandwiches": 3.0,
    "Bubble Tea": 2.5,
    "Bubble Tea Upgrades": .05,
    "Tea": 0.5,
    "Sparkling Tea Drinks": 1.5,
    "Kids Drinks": 1.0,
    "Waffles": 2.0,
    "Kimchi Rice": 1.55,
    "Popcorn Chicken": 1.46,
    "Garlic Fries": 1.00,
    "Spam Musubi": 0.50,
}

item_relations = {
    "Espresso Drinks": {"Pastries": 0.2},
    "Pour Over Coffee": {"Pastries": 0.2},
    "Pastries": {"Espresso Drinks": 0.1, "Pour Over Coffee": 0.1, "Tea": 0.05, "Bubble Tea": 0.1},
    "Sandwiches": {"Espresso Drinks": 0.05, "Sparkling Tea Drinks": 0.1, "Bubble Tea": 0.1},
    "Bubble Tea": {"Waffles": 0.3, "Bubble Tea Upgrades": 0.2},
    "Bubble Tea Upgrades": {"Bubble Tea": 1},
    "Tea": {"Pastries": 0.1},
    "Sparkling Tea Drinks": {"Sandwiches": 0.05},
    "Kids Drinks": {"Pastries": 0.1},
    "Waffles": {"Bubble Tea": 0.3, "Bubble Tea Upgrades": 0.3, "Tea": 0.1},
    "Kimchi Rice": {"Bubble Tea": 0.1, "Bubble Tea Upgrades": 0.1},
    "Popcorn Chicken": {"Bubble Tea": 0.2, "Bubble Tea Upgrades": 0.1},
    "Garlic Fries": {"Bubble Tea": 0.1, "Bubble Tea Upgrades": 0.1},
    "Spam Musubi": {"Bubble Tea": 0.1, "Bubble Tea Upgrades": 0.1},
}

sample_orders_by_persona = {persona: [] for persona in personas.keys()} 

def adjust_probability(item, selected_items):
    adjustment = 0
    for related_item, effect in item_relations.get(item, {}).items():
        if related_item in selected_items:
            adjustment += effect
    return adjustment

def adjust_probability(item, selected_items):
    adjustment = 0
    for related_item, effect in item_relations.get(item, {}).items():
        if related_item in selected_items:
            adjustment += effect
    return adjustment

def calculate_purchases_and_revenue(estimated_total_customers):
    total_purchases = {item: 0 for item in prices.keys()}
    total_revenue = {item: 0 for item in prices.keys()}
    total_costs = {item: 0 for item in costs.keys()}  # New dictionary to track total costs
    total_profit = {item: 0 for item in prices.keys()}  # New dictionary to track total profit
    
    for persona, data in personas.items():
        num_customers_in_persona = (data['percentage'] / 100) * estimated_total_customers
        
        for _ in range(int(num_customers_in_persona)):
            selected_items = []
            
            for item, probability in data['purchases'].items():
                adjusted_probability = probability + adjust_probability(item, selected_items)
                if random.random() < adjusted_probability:
                    total_purchases[item] += 1
                    total_revenue[item] += prices[item]
                    total_costs[item] += costs[item]  # Accumulate costs
                    selected_items.append(item)
                    
            if not selected_items:
                items = list(data['purchases'].keys())
                probabilities = list(data['purchases'].values())
                item = random.choices(items, weights=probabilities, k=1)[0]
                
                total_purchases[item] += 1
                total_revenue[item] += prices[item]
                total_costs[item] += costs[item]
                selected_items.append(item)
            
            if len(sample_orders_by_persona[persona]) < 5:
                sample_orders_by_persona[persona].append(selected_items)
    
    # Calculate total profit for each item
    for item in total_profit.keys():
        total_profit[item] = total_revenue[item] - total_costs[item]
    
    total_revenue_sum = sum(total_revenue.values())
    total_costs_sum = sum(total_costs.values())
    total_profit_sum = sum(total_profit.values())
    
    return total_purchases, total_revenue, total_costs, total_profit, total_revenue_sum, total_costs_sum, total_profit_sum, sample_orders_by_persona

def calculate_purchases_and_revenue_monte_carlo(estimated_total_customers, num_simulations):
    # Initialize accumulators for total purchases, revenue, costs, and profit for each item
    item_purchases_sums = {item: 0 for item in prices.keys()}
    simulations_revenue = []
    simulations_costs = []
    simulations_profit = []
    
    for i in range(num_simulations):
        # Run the simulation and unpack all the additional return values properly
        total_purchases, total_revenue, total_costs, total_profit, total_revenue_sum, total_costs_sum, total_profit_sum, _ = calculate_purchases_and_revenue(estimated_total_customers)
        
        # Accumulate total purchases, revenue, costs, and profit for each item
        for item in total_purchases.keys():
            item_purchases_sums[item] += total_purchases[item]
        simulations_revenue.append(total_revenue_sum)
        simulations_costs.append(total_costs_sum)
        simulations_profit.append(total_profit_sum)
        
        # Optionally log completion of each simulation
        if (i+1) % 1000 == 0 or i == num_simulations - 1:
            print(f"Simulation {i+1}/{num_simulations} completed.")
    
    # Calculate the average total purchases, revenue, costs, and profit across all simulations
    avg_item_purchases = {item: total / num_simulations for item, total in item_purchases_sums.items()}
    avg_total_revenue = sum(simulations_revenue) / num_simulations
    avg_total_costs = sum(simulations_costs) / num_simulations
    avg_total_profit = sum(simulations_profit) / num_simulations
    
    return avg_item_purchases, avg_total_revenue, avg_total_costs, avg_total_profit

estimated_total_customers = 2500
num_simulations = 5000
# Adjusted call to the Monte Carlo simulation function
avg_item_purchases, avg_total_revenue, avg_total_costs, avg_total_profit = calculate_purchases_and_revenue_monte_carlo(estimated_total_customers, num_simulations)

# Displaying the results
print("Average Purchases for Each Menu Item:")
for item, avg_purchases in avg_item_purchases.items():
    print(f"{item}: {avg_purchases:.2f}")
print(f"\nAverage Total Revenue: ${avg_total_revenue:.2f}")
print(f"Average Total Costs: ${avg_total_costs:.2f}")
print(f"Average Gross Margin (Revenue - COGS): ${avg_total_profit:.2f}")

print('--------- Sample Orders --------- ')

# Iterate through each persona to display their sample orders
for persona, orders in sample_orders_by_persona.items():
    print(f"\nSample Orders for {persona}:")
    for order_index, order in enumerate(orders, start=1):
        print(f"  Order {order_index}: {order}")
# Out:
# Simulation 1000/5000 completed.
# Simulation 2000/5000 completed.
# Simulation 3000/5000 completed.
# Simulation 4000/5000 completed.
# Simulation 5000/5000 completed.
# Average Purchases for Each Menu Item:
# Espresso Drinks: 790.19
# Pour Over Coffee: 460.42
# Pastries: 736.94
# Sandwiches: 787.18
# Bubble Tea: 1163.12
# Bubble Tea Upgrades: 737.94
# Tea: 114.13
# Sparkling Tea Drinks: 241.20
# Kids Drinks: 375.00
# Waffles: 408.06
# Kimchi Rice: 145.13
# Popcorn Chicken: 436.82
# Garlic Fries: 293.20
# Spam Musubi: 334.53
#
# Average Total Revenue: $38448.06
# Average Total Costs: $11984.27
# Average Gross Margin (Revenue - COGS): $26463.78
# --------- Sample Orders ---------
#
# Sample Orders for The Morning Commuter:
#   Order 1: ['Spam Musubi', 'Bubble Tea', 'Pour Over Coffee', 'Sandwiches', 'Waffles']
#   Order 2: ['Waffles']
#   Order 3: ['Espresso Drinks', 'Waffles']
#   Order 4: ['Spam Musubi', 'Bubble Tea', 'Espresso Drinks', 'Pastries']
#   Order 5: ['Bubble Tea', 'Pastries', 'Sandwiches', 'Waffles']
#
# Sample Orders for The Student:
#   Order 1: ['Bubble Tea Upgrades', 'Waffles']
#   Order 2: ['Bubble Tea']
#   Order 3: ['Kimchi Rice']
#   Order 4: ['Bubble Tea Upgrades', 'Waffles', 'Sandwiches']
#   Order 5: ['Spam Musubi', 'Bubble Tea', 'Bubble Tea Upgrades', 'Waffles', 'Sandwiches', 'Popcorn Chicken']
#
# Sample Orders for The Remote Worker:
#   Order 1: ['Bubble Tea']
#   Order 2: ['Kimchi Rice', 'Bubble Tea', 'Pour Over Coffee', 'Pastries', 'Sandwiches']
#   Order 3: ['Espresso Drinks']
#   Order 4: ['Spam Musubi', 'Bubble Tea']
#   Order 5: ['Espresso Drinks']
#
# Sample Orders for The Socializer:
#   Order 1: ['Popcorn Chicken']
#   Order 2: ['Popcorn Chicken']
#   Order 3: ['Bubble Tea Upgrades', 'Garlic Fries']
#   Order 4: ['Tea']
#   Order 5: ['Bubble Tea Upgrades', 'Sparkling Tea Drinks', 'Popcorn Chicken']
#
# Sample Orders for The Health-Conscious Customer:
#   Order 1: ['Kimchi Rice', 'Sparkling Tea Drinks']
#   Order 2: ['Waffles']
#   Order 3: ['Sparkling Tea Drinks', 'Sandwiches']
#   Order 4: ['Sandwiches']
#   Order 5: ['Kimchi Rice', 'Tea', 'Sandwiches']
#
# Sample Orders for The Family Outing:
#   Order 1: ['Bubble Tea', 'Bubble Tea Upgrades', 'Kids Drinks', 'Pastries', 'Sandwiches', 'Popcorn Chicken', 'Garlic Fries']
#   Order 2: ['Bubble Tea', 'Bubble Tea Upgrades', 'Kids Drinks', 'Pastries', 'Sandwiches', 'Popcorn Chicken', 'Garlic Fries']
#   Order 3: ['Bubble Tea', 'Bubble Tea Upgrades', 'Kids Drinks', 'Pastries', 'Sandwiches', 'Garlic Fries']
#   Order 4: ['Bubble Tea', 'Bubble Tea Upgrades', 'Kids Drinks', 'Sandwiches', 'Popcorn Chicken', 'Garlic Fries']
#   Order 5: ['Bubble Tea', 'Bubble Tea Upgrades', 'Kids Drinks', 'Popcorn Chicken', 'Garlic Fries']
#
# Sample Orders for The Connoisseur:
#   Order 1: ['Pour Over Coffee']
#   Order 2: ['Pour Over Coffee', 'Espresso Drinks']
#   Order 3: ['Pour Over Coffee']
#   Order 4: ['Espresso Drinks']
#   Order 5: ['Pour Over Coffee', 'Espresso Drinks']
#
# Sample Orders for The Professional Freelancer:
#   Order 1: ['Espresso Drinks', 'Pour Over Coffee']
#   Order 2: ['Kimchi Rice', 'Espresso Drinks', 'Sparkling Tea Drinks', 'Bubble Tea']
#   Order 3: ['Espresso Drinks']
#   Order 4: ['Espresso Drinks', 'Pour Over Coffee', 'Sandwiches']
#   Order 5: ['Espresso Drinks', 'Pour Over Coffee', 'Sparkling Tea Drinks', 'Bubble Tea', 'Pastries']
